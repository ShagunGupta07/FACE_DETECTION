# %% [markdown]
# <a href="https://colab.research.google.com/github/ShagunGupta07/Image_Face_Detection/blob/main/image_face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %% [markdown]
# # IMAGE DETECTION

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread('/content/WhatsApp Image 2023-07-25 at 9.57.56 AM.jpeg',cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x624>

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
print(img)
# Out:
# [[[173 164 155]
#   [173 164 155]
#   [173 164 155]
#   ...
#   [167 162 153]
#   [167 162 153]
#   [167 162 153]]
#
#  [[173 164 155]
#   [173 164 155]
#   [173 164 155]
#   ...
#   [167 162 153]
#   [167 162 153]
#   [167 162 153]]
#
#  [[173 164 155]
#   [173 164 155]
#   [173 164 155]
#   ...
#   [167 162 153]
#   [167 162 153]
#   [167 162 153]]
#
#  ...
#
#  [[ 85 152 153]
#   [ 81 148 149]
#   [ 84 151 152]
#   ...
#   [140 150 168]
#   [140 150 168]
#   [139 149 167]]
#
#  [[ 86 153 154]
#   [ 77 144 145]
#   [ 79 146 147]
#   ...
#   [152 160 177]
#   [154 162 179]
#   [153 161 178]]
#
#  [[ 95 162 163]
#   [ 80 147 148]
#   [ 73 140 141]
#   ...
#   [145 153 170]
#   [153 161 178]
#   [155 163 180]]]

# %%
# display its shape
img.shape
# Out:
# (624, 1280, 3)

# %%
cv2.destroyAllWindows()

# %%
# height 1752 px and widtrh 1480 px
print('Image height:{}'.format(img.shape[0]))
print('Image weight:{}'.format(img.shape[1]))
# Out:
# Image height:624
# Image weight:1280

# %%
# resize the image to 1/3rd of its original and then display
h=int(img.shape[0]/3)
w=int(img.shape[1]/3)
resized_img=cv2.resize(img,(w,h))
cv2_imshow(resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=426x208>

# %% [markdown]
# # FACE DETECTION

# %%
# Face Detection

# create CascadeClassifier for finding faces
face_cascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
img=cv2.imread('/content/WhatsApp Image 2023-07-25 at 9.57.51 AM.jpeg')
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
# apply face_cascade to the gray image
faces=face_cascade.detectMultiScale(gray_img, scaleFactor=1.05,minNeighbors=5)
print(faces)
for x,y,w,h in faces:
  img=cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),3)
# Out:
# [[249  79 189 189]]

# %%
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=647x404>

# %%
import os
for filename in os.listdir( cv2.data.haarcascades ):
    print(filename)
# Out:
# haarcascade_upperbody.xml
# haarcascade_frontalcatface_extended.xml
# haarcascade_lefteye_2splits.xml
# haarcascade_license_plate_rus_16stages.xml
# haarcascade_frontalface_alt.xml
# haarcascade_righteye_2splits.xml
# haarcascade_frontalface_alt2.xml
# haarcascade_frontalface_alt_tree.xml
# haarcascade_profileface.xml
# haarcascade_eye.xml
# __init__.py
# haarcascade_frontalcatface.xml
# haarcascade_smile.xml
# haarcascade_lowerbody.xml
# haarcascade_frontalface_default.xml
# haarcascade_fullbody.xml
# __pycache__
# haarcascade_russian_plate_number.xml
# haarcascade_eye_tree_eyeglasses.xml

# %% [markdown]
# # VIDEO DETECTION

# %%
# Video Capturing
# create CascadeClassifier for finding faces
# face_cascade=cv2.CascadeClassifier('E:\BetaLab\July24\haarcascade_frontalface_default.xml')
face_cascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
# capture video from the laptop camera - your laptop camera will be on
cap=cv2.VideoCapture('/content/WIN_20200507_13_12_39_Pro.mp4')
print(cap)
cap.read()
# Out:
# < cv2.VideoCapture 0x7b206fc5f930>
# (True,
#  array([[[254, 255, 244],
#          [254, 255, 244],
#          [254, 255, 244],
#          ...,
#          [ 98, 153, 132],
#          [ 94, 155, 133],
#          [ 94, 155, 133]],
#
#         [[254, 255, 244],
#          [254, 255, 244],
#          [254, 255, 244],
#          ...,
#          [ 98, 153, 132],
#          [ 94, 155, 133],
#          [ 94, 155, 133]],
#
#         [[254, 255, 244],
#          [254, 255, 244],
#          [254, 255, 244],
#          ...,
#          [ 98, 153, 132],
#          [ 94, 155, 133],
#          [ 94, 155, 133]],
#
#         ...,
#
#         [[ 74,  52,  52],
#          [ 77,  55,  55],
#          [ 72,  56,  55],
#          ...,
#          [  0,   0,   1],
#          [  0,   0,   1],
#          [  0,   0,   1]],
#
#         [[ 74,  54,  54],
#          [ 78,  58,  58],
#          [ 73,  59,  58],
#          ...,
#          [  0,   0,   1],
#          [  0,   0,   1],
#          [  0,   0,   1]],
#
# ...

# %%
# while True:
#     ret,frame=cap.read() # read frame by frame
#     gray_frame=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#     faces=face_cascade.detectMultiScale(gray_frame,1.3,5)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# Out:
# Can't receive frame (stream end?). Exiting ...

# %%
# !pip install cv

# %%
faces=face_cascade.detectMultiScale(gray_frame,1.3,5)

# %%
 #display the blue rectangle around faces in the frame
for (x,y,w,h) in faces:
    cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)

# %%
# !curl
# Out:
# curl: try 'curl --help' or 'curl --manual' for more information

# %%
from google.colab.patches import cv2_imshow
 # show the frame
# cv2.imshow('img',frame)
cv2_imshow(gray)
key=cv2.waitKey(1)
if key==ord('q'):
  sys.exit()
# Out:
# <PIL.Image.Image image mode=L size=1280x720>
